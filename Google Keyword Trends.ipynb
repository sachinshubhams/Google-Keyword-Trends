# %% [markdown]
# How to get Google Keyword Trends using Python

# %%
#pip install pytrends
#pip install plotly==4.14.3

# %%
from pytrends.request import TrendReq
import plotly.express as plot
import pandas as pd

# %%
pytrend=TrendReq(hl='en-US',tz=360)

# %%
trendy_keywords = ['Machine Learning','Deep Learning','Data Science','Artificial Intelligence','Computer Vision']
kw = trendy_keywords
trend_Req=TrendReq()

# %%
trend_Req.build_payload(trendy_keywords)

# %%
#interest over time
iot=trend_Req.interest_over_time()
iot
# Out:
#             Machine Learning  Deep Learning  Data Science  \
# date
# 2016-04-17                32             12            21
# 2016-04-24                30             13            19
# 2016-05-01                29             12            20
# 2016-05-08                29             13            25
# 2016-05-15                31             13            24
# ...                      ...            ...           ...
# 2021-03-07                70             25            60
# 2021-03-14                77             27            62
# 2021-03-21                76             25            56
# 2021-03-28                71             23            59
# 2021-04-04                72             24            63
#
#             Artificial Intelligence  Computer Vision  isPartial
# date
# 2016-04-17                       25                5      False
# 2016-04-24                       23                5      False
# ...

# %%
#interest by region
ior=trend_Req.interest_by_region()
ior
# Out:
#                 Machine Learning  Deep Learning  Data Science  \
# geoName
# Afghanistan                    0              0             0
# Albania                        0              0             0
# Algeria                        0              0             0
# American Samoa                 0              0             0
# Andorra                        0              0             0
# ...                          ...            ...           ...
# Western Sahara                 0              0             0
# Yemen                          0              0             0
# Zambia                         0              0             0
# Zimbabwe                       0              0             0
# Åland Islands                  0              0             0
#
#                 Artificial Intelligence  Computer Vision
# geoName
# Afghanistan                           0                0
# Albania                               0                0
# ...

# %%
# Related Queries, returns a dictionary of dataframes
related_keywords = trend_Req.related_queries()
print(related_keywords)
# Out:
# {'Machine Learning': {'top':                                        query  value
# 0                    machine learning python    100
# 1                                     python     99
# 2                   what is machine learning     59
# 3                                         ai     54
# 4                        ai machine learning     53
# 5             machine learning deep learning     51
# 6             deep learning machine learning     51
# 7                              deep learning     49
# 8                    machine learning google     47
# 9                       machine learning pdf     44
# 10               machine learning algorithms     38
# 11                   machine learning course     37
# 12                    machine learning model     34
# 13                   artificial intelligence     33
# 14                              data science     32
# 15             data science machine learning     32
# ...

# %%
#Filtering Rising and Top Queries
# for rising trending keywords ML 
rising_keyword_ML = related_keywords.get(kw[0]).get('rising')
# for top trending keywords ML
top_keyword_ML = related_keywords.get(kw[0]).get('top')

# for rising trending keywords DS 
rising_keyword_DS = related_keywords.get(kw[2]).get('rising')
# for top trending keywords DS
top_keyword_DS = related_keywords.get(kw[2]).get('top')

print("-------------------- RISING KEYWORDS : Machine Learning --------------------")
print("\n")
print(rising_keyword_ML)
print("\n")
print("-------------------- TOP KEYWORDS :  Machine Learning --------------------")
print("\n")
print(top_keyword_ML)
print("\n")
print("-------------------- RISING KEYWORDS : Data Science --------------------")
print("\n")
print(rising_keyword_DS)
print("\n")
print("-------------------- TOP KEYWORDS :  Data Science --------------------")
print("\n")
print(top_keyword_DS)
# Out:
# -------------------- RISING KEYWORDS : Machine Learning --------------------
#
#
#                                                 query  value
# 0   hands on machine learning with scikit-learn an...  17950
# 1                google machine learning crash course  10650
# 2   hands on machine learning with scikit-learn an...   9700
# 3                  aws machine learning certification   8850
# 4                           machine learning yearning   8850
# 5                           machine learning fairness   6800
# 6                     ai and machine learning courses   6650
# 7                             machine learning cơ bản   6550
# 8              the hundred-page machine learning book   5100
# 9   python for data science and machine learning b...   5000
# 10                              lime machine learning   4800
# 11                             machine learning memes   3650
# 12  traffic prediction for intelligent transportat...   2950
# ...

# %%
plot.line(ior[trendy_keywords])
# Out:
# <div>                            <div id="855735d2-60e4-40c6-a54e-756179f0140a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("855735d2-60e4-40c6-a54e-756179f0140a")) {                    Plotly.newPlot(                        "855735d2-60e4-40c6-a54e-756179f0140a",                        [{"hovertemplate": "variable=Machine Learning<br>geoName=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Machine Learning", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Machine Learning", "showlegend": true, "type": "scattergl", "x": ["Afghanistan", "Albania", "Algeria", "American Samoa", "Andorra", "Angola", "Anguilla", "Antarctica", "Antigua & Barbuda", "Argentina", "Armenia", "Aruba", "Australia", "Austria", "Azerbaijan", "Bahama
# ...

# %%
plot.line(iot[trendy_keywords])
# Out:
# <div>                            <div id="65a5ad47-6ac0-47f9-bc01-9c1e82fae0a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65a5ad47-6ac0-47f9-bc01-9c1e82fae0a7")) {                    Plotly.newPlot(                        "65a5ad47-6ac0-47f9-bc01-9c1e82fae0a7",                        [{"hovertemplate": "variable=Machine Learning<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Machine Learning", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Machine Learning", "showlegend": true, "type": "scattergl", "x": ["2016-04-17T00:00:00", "2016-04-24T00:00:00", "2016-05-01T00:00:00", "2016-05-08T00:00:00", "2016-05-15T00:00:00", "2016-05-22T00:00:00", "2016-05-29T00:00:00", "2016-06-05T00:00:00", "2016-06-12T00:00:00
# ...
