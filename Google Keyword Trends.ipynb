# %% [markdown]
# How to get Google Keyword Trends using Python

# %%
#pip install pytrends
#pip install plotly==4.14.3

# %%
from pytrends.request import TrendReq
import plotly.express as plot
import pandas as pd

# %%
pytrend=TrendReq(hl='en-US',tz=360)

# %%
trendy_keywords = ['Machine Learning','Deep Learning','Data Science','Artificial Intelligence','Computer Vision']
trend_Req=TrendReq()

# %%
trend_Req.build_payload(trendy_keywords)

# %%
#interest over time
iot=trend_Req.interest_over_time()
iot
# Out:
#             Machine Learning  Deep Learning  Data Science  \
# date
# 2016-04-17                31             12            18
# 2016-04-24                31             14            21
# 2016-05-01                31             11            23
# 2016-05-08                32             12            26
# 2016-05-15                32             15            24
# ...                      ...            ...           ...
# 2021-03-07                68             25            57
# 2021-03-14                79             23            65
# 2021-03-21                78             25            64
# 2021-03-28                73             25            66
# 2021-04-04                78             23            67
#
#             Artificial Intelligence  Computer Vision isPartial
# date
# 2016-04-17                       25                6     False
# 2016-04-24                       26                6     False
# 2016-05-01                       25                5     False
# ...

# %%
#interest by region
ior=trend_Req.interest_by_region()
ior
# Out:
#                 Machine Learning  Deep Learning  Data Science  \
# geoName
# Afghanistan                    0              0             0
# Albania                        0              0             0
# Algeria                        0              0             0
# American Samoa                 0              0             0
# Andorra                        0              0             0
# ...                          ...            ...           ...
# Western Sahara                 0              0             0
# Yemen                          0              0             0
# Zambia                         0              0             0
# Zimbabwe                       0              0             0
# Åland Islands                  0              0             0
#
#                 Artificial Intelligence  Computer Vision
# geoName
# Afghanistan                           0                0
# Albania                               0                0
# ...

# %%
# Related Queries, returns a dictionary of dataframes
related_keywords = trend_Req.related_queries()
print(related_keywords)
# Out:
# {'Machine Learning': {'top':                                        query  value
# 0                    python machine learning    100
# 1                                     python    100
# 2                   what is machine learning     60
# 3                        ai machine learning     56
# 4                                         ai     55
# 5             machine learning deep learning     53
# 6                    google machine learning     53
# 7                              deep learning     51
# 8                       machine learning pdf     42
# 9                    machine learning course     36
# 10                    machine learning model     35
# 11               machine learning algorithms     33
# 12                              data science     32
# 13                   artificial intelligence     31
# 14  machine learning artificial intelligence     31
# 15                machine learning algorithm     27
# ...

# %%
#Filtering Rising and Top Queries
# for rising trending keywords
rising_keyword = related_queries_dict.get(kw).get('rising')
# for top trending keywords
top_keyword = related_queries_dict.get(kw).get('top')
print("----- RISING KEYWORDS -----")
print(rising_keyword)
print("\n")
print("----- TOP KEYWORDS -----")
print(top_keyword)
# Out:
# ----- RISING KEYWORDS -----
#                                                 query  value
# 0                                             pytorch  27550
# 1   difference between deep learning and machine l...  19100
# 2   hands-on machine learning with scikit-learn an...  15750
# 3   hands on machine learning with scikit-learn an...  13150
# 4                google machine learning crash course  11350
# 5                  aws machine learning certification   9900
# 6                              epoch machine learning   7900
# 7   hands on machine learning with scikit-learn an...   7900
# 8            feature engineering for machine learning   7450
# 9                                        google colab   6100
# 10                          machine learning yearning   5950
# 11                                          data lake   4850
# 12             advances in financial machine learning   4700
# 13  traffic prediction for intelligent transportat...   3950
# ...

# %%
plot.line(ior[trendy_keywords])
# Out:
# <div>                            <div id="fe32ec62-252f-41a0-bcd5-d68c9b81338d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe32ec62-252f-41a0-bcd5-d68c9b81338d")) {                    Plotly.newPlot(                        "fe32ec62-252f-41a0-bcd5-d68c9b81338d",                        [{"hovertemplate": "variable=Machine Learning<br>geoName=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Machine Learning", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Machine Learning", "showlegend": true, "type": "scattergl", "x": ["Afghanistan", "Albania", "Algeria", "American Samoa", "Andorra", "Angola", "Anguilla", "Antarctica", "Antigua & Barbuda", "Argentina", "Armenia", "Aruba", "Australia", "Austria", "Azerbaijan", "Bahama
# ...

# %%
plot.line(iot[trendy_keywords])
# Out:
# <div>                            <div id="911511b7-9f05-40d4-bd85-df035c145956" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("911511b7-9f05-40d4-bd85-df035c145956")) {                    Plotly.newPlot(                        "911511b7-9f05-40d4-bd85-df035c145956",                        [{"hovertemplate": "variable=Machine Learning<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Machine Learning", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Machine Learning", "showlegend": true, "type": "scattergl", "x": ["2016-04-17T00:00:00", "2016-04-24T00:00:00", "2016-05-01T00:00:00", "2016-05-08T00:00:00", "2016-05-15T00:00:00", "2016-05-22T00:00:00", "2016-05-29T00:00:00", "2016-06-05T00:00:00", "2016-06-12T00:00:00
# ...
